# %% [markdown]
# CRIAR UMA TABELA:
#
#     create table pessoas(
#     id int PRIMARY KEY NOT NULL,
#     nome varchar(30) NOT NULL,
#     nascimento date,
#     sexo varchar(1),
#     peso decimal(5,2),
#     altura decimal(3,2),
#     nacionalidade varchar(20),
#     )

# %% [markdown]
# ___
# EXCLUIR TABELA:
#
#     DROP TABLE pessoas;

# %% [markdown]
# ___
# CRIAR CHAVES ESTRANGEIRAS - FOREIGN KEY:
# ![image.png](attachment:image.png)

# %% [markdown]
#     ALTER TABLE nome_tabela
#
#     ADD CONSTRAINT FK_nome_da_chave
#     FOREIGN KEY (id_xxx)                 << id_xxx: campo da tabela que está sendo alterada
#     REFERENCES nome_tabela_de_ligação (id_yyy);

# %% [markdown]
# ___
# EXCLUIR UMA CONSTRAINT:

# %% [markdown]
#     ALTER TABLE nome_table
#     DROP CONSTRAINT fk_blabla:

# %% [markdown]
# ____
# INSERIR DADOS NA TABELA - INSERT INTO:
# ![image.png](attachment:image.png)

# %% [markdown]
# ____
# MODIFICAR NOME DA COLUNA:
#
#      renomear a coluna Nome_Livro da tabela de livros (tbl_livros) para Titulo_Livro:
#    ![image.png](attachment:image.png)

# %% [markdown]
# ____
# MODIFICAR NOME DA TABELA:
#
#     renomear a tabela de livros, cujo nome atual é tbl_livros para tLivros:
#   ![image.png](attachment:image.png)
